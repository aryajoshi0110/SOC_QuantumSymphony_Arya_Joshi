# %% [markdown]
# Import necessary packages

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# TODO 1: Read the data from ```data.csv``` using ```pandas```

# %%
# Complete TODO 1
# Store the column labelleed X as a numpy array named X 
# Store the column labeled y as a numpy array named y
# Ensure that you reshape them properly

data = pd.read_csv('data.csv')

X = np.array(data['X'].values.reshape(-1, 1))
y = np.array(data['y'].values.reshape(-1, 1))

# %% [markdown]
# TODO 2: Complete the ```normalize``` function. For a numpy array X, normalized output will be
# ```(X - mean(X))/standard_devaiation(X)```

# %%
def normalize(X):
    #Complete TODO 2
    mean = np.mean(X)
    std = np.std(X)
    return (X - mean) / std

X_norm = normalize(X)
y_norm = normalize(y)

# Initialize parameters
theta = np.random.randn(2, 1)  # We have 2 parameters (theta_0 and theta_1)

# %% [markdown]
# TODO 3: Complete the function ```complete_cost``` function below. Refer to Problem statement for the cost (error) function for linear regression.
#
# Here, ```X``` : np.array of x-coordinates of points
#
# ```y``` : np.array of y-coordinates of points
#
# ```theta``` : np.array of parameters

# %%
def compute_cost(X, y, theta):
    m = len(y)
    X_b = np.c_[np.ones((m, 1)), X]  # Add bias term (x0 = 1)
    #Complete TODO 3
    # Compute the cost function
    cost = np.sum((np.dot(X_b, theta) - y) ** 2) / m  
    return cost

# %% [markdown]
# TODO 4: Implement Gradient Descent for linear regression according to algorithm given in the Problem Statement. Your only task is to update theta properly by finding the gradient correctly.

# %%
def gradient_descent(X, y, theta, learning_rate, iterations):
    m = len(y)
    X_b = np.c_[np.ones((m, 1)), X]  # Add bias term (x0 = 1)
    cost_history = []

    for _ in range(iterations):
        #Complete TODO 4
        # Update theta 
        cost = compute_cost(X, y, theta)
        cost_history.append(cost)
        theta = theta - learning_rate*2*(1/m)*np.sum((np.dot(X_b,theta) - y)*X_b)

    return theta, cost_history

# %% [markdown]
# TODO 5: Find ```theta_optimal``` and ```cost_history``` by calling the ```gradient_descent``` function. Also, print them.

# %%
learning_rate = 0.1
iterations = 1000

#Complete TODO 5
theta_optimal , cost_history = gradient_descent(X, y, theta , learning_rate, iterations)
print(f"θ = " , theta_optimal)
print(f"Cost history = " , cost_history)
# Out:
# θ =  [[3.54808611]
#  [3.3651389 ]]
# Cost history =  [39.50395981282495, 2.149055220380881, 0.9799862810470293, 0.9433987914033901, 0.9422537396845527, 0.9422179038441719, 0.9422167823162663, 0.9422167472166336, 0.9422167461181463, 0.9422167460837675, 0.9422167460826917, 0.9422167460826577, 0.942216746082657, 0.942216746082657, 0.9422167460826567, 0.942216746082657, 0.9422167460826568, 0.9422167460826567, 0.9422167460826572, 0.9422167460826567, 0.9422167460826568, 0.9422167460826572, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082657, 0.942216746082 ...

# %%
m = len(y)
X_b = np.c_[np.ones((m, 1)), X]
plt.scatter(X , y , s =1 )
plt.plot(X, np.dot(X_b,theta_optimal) , color= 'black')
plt.show()
